# %% [markdown]
# <a href="https://colab.research.google.com/github/sudharshini-codes/Python-daily-practice/blob/main/Day9_Smallest_and_largest_numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=float(input("Enter the first number:"))
b=float(input("Enter the second number:"))
largest_number=max(a,b)
smallest_number=min(a,b)
print("The largest number is:",largest_number)
print("The smallest number is:",smallest_number)
# Out:
# Enter the first number:10
# Enter the second number:5
# The largest number is: 10.0
# The smallest number is: 5.0

# %%
a=float(input("Enter the first number:"))
b=float(input("Enter the second number:"))
c=float(input("Enter the third number:"))
largest_number=max(a,b,c)
smallest_number=min(a,b,c)
print("The largest number is:",largest_number)
print("The smallest number is:",smallest_number)
# Out:
# Enter the first number:10
# Enter the second number:20
# Enter the third number:30
# The largest number is: 30.0
# The smallest number is: 10.0

# %% [markdown]
# #Program1- To find the smallest and largest of two numbers
# #Program2- To find the smallest and largest of three numbers
