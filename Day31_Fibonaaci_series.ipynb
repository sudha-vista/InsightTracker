# %% [markdown]
# <a href="https://colab.research.google.com/github/sudharshini-codes/Python-daily-practice/blob/main/Day31_Fibonaaci_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N = int(input("Enter how many terms you want: "))

a = 0
b = 1
count = 0

while count < N:
    print(a)
    c = a + b
    a = b
    b = c
    count = count + 1

# %% [markdown]
# 💙 Imagine this as a story 👇
#
# You have two numbers in your hands:
# 🖐️ Left hand = a
# ✋ Right hand = b
#
# At the start:
#
# Left hand (a) = 0
# Right hand (b) = 1
#
#
# ---
#
# 🪄 Step 1:
#
# 📢 Print what’s in left hand → 0
#
# Now make a new number c = a + b → 0 + 1 = 1
#
# Then shift:
#
# Move right hand to left → a = b
#
# Put new number in right hand → b = c
#
#
# Now:
# a = 1, b = 1
#
#
# ---
#
# 🪄 Step 2:
#
# 📢 Print left hand → 1
#
# Make c = a + b → 1 + 1 = 2
# Shift again:
# a = 1, b = 2
#
#
# ---
#
# 🪄 Step 3:
#
# 📢 Print left hand → 1 c = 1 + 2 = 3
# Shift → a = 2, b = 3
#
#
# ---
#
# 🪄 Step 4:
#
# 📢 Print left hand → 2 c = 2 + 3 = 5
# Shift → a = 3, b = 5
#
#
# ---
#
# 🪄 Step 5:
#
# 📢 Print left hand → 3 c = 3 + 5 = 8
# Shift → a = 5, b = 8
#
# Now we finished 5 rounds → Stop 💫
#
# ✅ Output:
#
# 0
# 1
# 1
# 2
# 3
#
#
# ---
#
#
#
# So:
#
#
# 🌼 Meaning:
#
# Each new number = sum of the previous two numbers
#
# 👉 Example:
# 0, 1, 1, 2, 3, 5, 8, 13 …
#
#
# ---
#
# 💙 Main Idea:
#
# We use two variables → a and b
#
# a → current number (we print this)
#
# b → next number
# and
#
# c = a + b → new number (temporary)
#
#
# Then we shift forward each loop:
#
# a = b
# b = c
#
#
# * Loop repeats this process
#
#
# *  Variables a, b, and c keep updating
#
#
# *  We print a every round
