# %% [markdown]
# <a href="https://colab.research.google.com/github/sudharshini-codes/Python-daily-practice/blob/main/Day11_Type_conversion(str_to_int%2C_float_to_int).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Implict type conversion

a=10   #int
b=2.5  #float
c=a+b  #int+float=float

print("value of c:",c,type(c))
# Out:
# value of c: 12.5 <class 'float'>

# %%
# Explicit type conversion(Manual)

a="25"      #string
b=int(a)    #string to integer
c=float(a)  #string to float
d=bool(a)   #string to bool

print("value of b:",b,type(b))
print("value of c:",c,type(c))
print("value of d:",d,type(d))
# Out:
# value of b: 25 <class 'int'>
# value of c: 25.0 <class 'float'>
# value of d: True <class 'bool'>

# %% [markdown]
# # Program1- Implicit type conversion(automatic)
#
# # Program- Explicit type conversion(Manual)
#
#
# **Notes**
#  Implicit conversion- Python automatically converts one data type to another.
#
#  Explicit coversion- Here, Python didn't convert automatically...you did it manually.
#
# when you convert a number to bool:
#
# if value= 0 , then bool value becomes false
#
# if value= any non zero number(1,2,-7) , then bool value becomes true.

# %%
# taking input from user..

a=input("Enter first number:")
b=input("Enter second number:")

#Convert to int before adding

sum=int(a)+int(b)
print(sum)
# Out:
# Enter first number:23
# Enter second number:1
# 24

# %% [markdown]
# Python always takes user input as a string, even if you type a number.
#
# Converting int before adding because... if we don't convert,python joins them as strings.
# "23"+"1"="24"

# %%
#float to int

a=7.8
b=int(a)
print("converted:",b,type(b))
# Out:
# converted: 7 <class 'int'>
