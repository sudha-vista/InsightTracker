# %% [markdown]
# <a href="https://colab.research.google.com/github/sudharshini-codes/Python-daily-practice/blob/main/Day20_Expressions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=int(input("Enter frst number:"))
num2=int(input("Enter second number:"))
num3=int(input("Enter third number:"))
#expressions

sq_sum=(num1**2)+(2*num1*num2)+(num2**2)
sq_diff=(num1**2)-(2*num1*num2)+(num2**2)
diff_sqs=(num1**2)-(num2**2)
thre_vari_sq=(num1**2)+(num2**2)+(num3**2)+(2*num1*num2)+(2*num2*num3)+(2*num3*num1)
cube_sum=(num1**3)+(3*(num1**2)*num2)+(3*num1*(num2**2))+(num2**3)
cube_diff=(num1**3)+(3*(num1**2)*num2)+(3*num1*(num2**2))-(num2**3)

print("(a + b)² =", sq_sum)
print("(a - b)² =", sq_diff)
print("a² - b² =", diff_sqs)
print("(a + b + c)² =", thre_vari_sq)
print("(a + b)³ =", cube_sum)
print("(a - b)³ =", cube_diff)
# Out:
# Enter frst number:12
# Enter second number:14
# Enter third number:16
# (a + b)² = 676
# (a - b)² = 4
# a² - b² = -52
# (a + b + c)² = 1764
# (a + b)³ = 17576
# (a - b)³ = 12088
