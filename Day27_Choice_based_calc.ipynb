# %% [markdown]
# <a href="https://colab.research.google.com/github/sudharshini-codes/Python-daily-practice/blob/main/Day27_Choice_based_calc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
   print("1.add 2.sub 3.mul 4.div")
   choice=int(input("Enter your choice(1-4):"))
   num1=int(input("Enter your frst number:"))
   num2=int(input("Enter your second number:"))
   if choice==1:
      print("Addition:",num1+num2)
   elif choice==2:
      print("Subtraction:",num1-num2)
   elif choice==3:
      print("Multiplication:",num1*num2)
   elif choice==4:
      print("Division:",num1/num2)
   else:
      print("Invalid choice")
      break
# Out:
# 1.add 2.sub 3.mul 4.div
# Enter your choice(1-4):1
# Enter your frst number:20
# Enter your second number:10
# Addition: 30
# 1.add 2.sub 3.mul 4.div
# Enter your choice(1-4):2
# Enter your frst number:40
# Enter your second number:20
# Subtraction: 20
# 1.add 2.sub 3.mul 4.div
# Enter your choice(1-4):3
# Enter your frst number:10
# Enter your second number:10
# Multiplication: 100
# 1.add 2.sub 3.mul 4.div
# Enter your choice(1-4):4
# Enter your frst number:60
# Enter your second number:30
# Division: 2.0
# 1.add 2.sub 3.mul 4.div
# Enter your choice(1-4):7
# Enter your frst number:40
# Enter your second number:30
# Invalid choice
