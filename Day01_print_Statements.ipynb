# %% [markdown]
# <a href="https://colab.research.google.com/github/sudharshini-codes/Python-daily-practice/blob/main/Day1_print_Statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %%
name='priya'
age=18
college="st.annes"

print("Name:",name)
print("Age:",age)
print("College:",college)
# Out:
# Name: priya
# Age: 18
# College: st.annes

# %% [markdown]
# Two small programs:
# #program1:print hello world
# #program2:print name/age/college
