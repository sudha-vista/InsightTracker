# %% [markdown]
# <a href="https://colab.research.google.com/github/sudharshini-codes/Python-daily-practice/blob/main/Day24_Discount_calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Amount=int(input("Enter total purchased amount:"))
if Amount>=5000:
   Discount=Amount*0.20
   Discount=round(Discount,2)
   print("20% discount applied")
elif Amount>=3000:
   Discount=Amount*0.15
   Discount=round(Discount,2)
   print("15% discount applied ")
else:
   Discount=Amount*0.10
   Discount=round(Discount,2)
   print("10% discount applied ")

Final_amount=Amount-Discount

print("Amount purchased:",Amount)
print("Discount applied:", Discount)
print("Final amount:",Final_amount)
# Out:
# Enter total purchased amount:9000
# 20% discount applied
# Amount purchased: 9000
# Discount applied: 1800.0
# Final amount: 7200.0
