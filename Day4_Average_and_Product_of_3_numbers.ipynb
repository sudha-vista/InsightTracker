# %% [markdown]
# <a href="https://colab.research.google.com/github/sudharshini-codes/Python-daily-practice/blob/main/Day4_Average_and_Product_of_3_numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=float(input("Enter the first number:"))
num2=float(input("Enter the second number:"))
num3=float(input("Enter the third number:"))
average=(num1+num2+num3)/3
print("Average of 3 numbers:",average)
# Out:
# Enter the first number:10
# Enter the second number:30
# Enter the third number:20
# Average of 3 numbers: 20.0

# %%
A=float(input("Enter the first no."))
B=float(input("Enter the second no."))
C=float(input("Enter the third no."))
D=float(input("Enter the fourth no."))
product=A*B*C
print("Product of 3 numbers:",product)
# Out:
# Enter the first no.2
# Enter the second no.2
# Enter the third no.2
# Enter the fourth no.10
# Product of 3 numbers: 8.0

# %% [markdown]
# Average and product of 3 numbers
#
# * Program1- To find the Average of 3 numbers
# * Program2- To find the Product of 3 numbers

# %% [markdown]
# **Notes for program1**
#
#
# * Average formula- Sum of all values/Number of values
# * Average syntax- (a+b+c+..)/n
# * The average gives the overall or common value of the numbers.
