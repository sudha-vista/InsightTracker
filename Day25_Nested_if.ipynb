# %% [markdown]
# <a href="https://colab.research.google.com/github/sudharshini-codes/Python-daily-practice/blob/main/Day25_Nested_if.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks = int(input("Enter your marks: "))

if marks >= 50:               # 1️⃣ Check if passed
    if marks >= 90:           # 2️⃣ Check if excellent
        print("Excellent! ")
    else:
        print("You Passed ")
else:
    print("You Failed ")
# Out:
# Enter your marks: 85
# You Passed
