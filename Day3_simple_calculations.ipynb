# %% [markdown]
# <a href="https://colab.research.google.com/github/sudharshini-codes/Python-daily-practice/blob/main/Day3_simple_calculations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A=int(input("Enter first number:"))
B=int(input("Enter second number:"))
c=int(input("Enter third number:"))
sum=A+B
print("ADDITION OF TWO NUMBERS IS:",sum)
# Out:
# Enter first number:70
# Enter second number:30
# Enter third number:50
# ADDITION OF TWO NUMBERS IS: 100

# %%
L=int(input("Enter first number:"))
M=int(input("Enter second number:"))
difference=L-M
print("subraction of two numbers is:",difference)
# Out:
# Enter first number:90
# Enter second number:10
# subraction of two numbers is: 80

# %% [markdown]
# Simple Calculations
#
# #Program1: Add 2 numbers
#
# #Program2: Subtract two numbers
