# %% [markdown]
# <a href="https://colab.research.google.com/github/sudharshini-codes/Python-daily-practice/blob/main/Day2_Input_Output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("Enter your name:")
age=input("Enter your age:")

print("Hello",name+"!","you are",age,"years old")
# Out:
# Enter your name:sudha
# Enter your age:18
# Hello sudha! you are 18 years old

# %%
print("Dream is not that which you see while sleeping:")
print("It is something that does not let you sleep.")
print("-Dr.A.P.J.ABDUL KALAM")
# Out:
# Dream is not that which you see while sleeping:
# It is something that does not let you sleep.
# -Dr.A.P.J.ABDUL KALAM

# %% [markdown]
# Programs that take input from the user and display formatted output.
#
# #program1: Greeting using user input
# #Program2: print a poem or quotes line by line
